# %%
# !pip install ploty
# !pip install cufflinks
# Out:
# ERROR: Could not find a version that satisfies the requirement ploty (from versions: none)
# ERROR: No matching distribution found for ploty
# ...

# %%
#import requirements packages
import pandas as pd
import numpy as np
import matplotlib as plt
import seaborn as sns
import cufflinks as cfg

# %%
#load a dataset
pd.read_csv(r"C:\Users\hp\Downloads\goalscorers.csv\goalscorers.csv")
# Out:
#              date  home_team away_team       team            scorer  minute  \
# 0      1916-07-02      Chile   Uruguay    Uruguay   José Piendibene    44.0
# 1      1916-07-02      Chile   Uruguay    Uruguay  Isabelino Gradín    55.0
# 2      1916-07-02      Chile   Uruguay    Uruguay  Isabelino Gradín    70.0
# 3      1916-07-02      Chile   Uruguay    Uruguay   José Piendibene    75.0
# 4      1916-07-06  Argentina     Chile  Argentina     Alberto Ohaco     2.0
# ...           ...        ...       ...        ...               ...     ...
# 41003  2022-12-18  Argentina    France  Argentina    Ángel Di María    36.0
# 41004  2022-12-18  Argentina    France     France     Kylian Mbappé    80.0
# 41005  2022-12-18  Argentina    France     France     Kylian Mbappé    81.0
# 41006  2022-12-18  Argentina    France  Argentina      Lionel Messi   109.0
# 41007  2022-12-18  Argentina    France     France     Kylian Mbappé   118.0
#
#        own_goal  penalty
# 0         False    False
# ...

# %%
#store in the variable name df
df=pd.read_csv(r"C:\Users\hp\Downloads\goalscorers.csv\goalscorers.csv")

# %%
#type of df
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
#to get data only above 4 rows
df.head(4)
# Out:
#          date home_team away_team     team            scorer  minute  \
# 0  1916-07-02     Chile   Uruguay  Uruguay   José Piendibene    44.0
# 1  1916-07-02     Chile   Uruguay  Uruguay  Isabelino Gradín    55.0
# 2  1916-07-02     Chile   Uruguay  Uruguay  Isabelino Gradín    70.0
# 3  1916-07-02     Chile   Uruguay  Uruguay   José Piendibene    75.0
#
#    own_goal  penalty
# 0     False    False
# 1     False    False
# 2     False    False
# 3     False    False

# %%
#to get data only below 4 rows
df.tail(4)
# Out:
#              date  home_team away_team       team         scorer  minute  \
# 41004  2022-12-18  Argentina    France     France  Kylian Mbappé    80.0
# 41005  2022-12-18  Argentina    France     France  Kylian Mbappé    81.0
# 41006  2022-12-18  Argentina    France  Argentina   Lionel Messi   109.0
# 41007  2022-12-18  Argentina    France     France  Kylian Mbappé   118.0
#
#        own_goal  penalty
# 41004     False     True
# 41005     False    False
# 41006     False    False
# 41007     False     True

# %%
#to get columns name
df.columns
# Out:
# Index(['date', 'home_team', 'away_team', 'team', 'scorer', 'minute',
#        'own_goal', 'penalty'],
#       dtype='object')

# %%
#to get info about columns
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 41008 entries, 0 to 41007
# Data columns (total 8 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   date       41008 non-null  object
#  1   home_team  41008 non-null  object
#  2   away_team  41008 non-null  object
#  3   team       41008 non-null  object
#  4   scorer     40959 non-null  object
#  5   minute     40750 non-null  float64
#  6   own_goal   41008 non-null  bool
#  7   penalty    41008 non-null  bool
# dtypes: bool(2), float64(1), object(5)
# memory usage: 2.0+ MB

# %%
#shows you quick statistic summary of data
df.describe()
# Out:
#              minute
# count  40750.000000
# mean      50.019166
# std       26.360859
# min        1.000000
# 25%       28.000000
# 50%       51.000000
# 75%       73.000000
# max      122.000000

# %%
#to convert data into the form of array
df.to_numpy()
# Out:
# array([['1916-07-02', 'Chile', 'Uruguay', ..., 44.0, False, False],
#        ['1916-07-02', 'Chile', 'Uruguay', ..., 55.0, False, False],
#        ['1916-07-02', 'Chile', 'Uruguay', ..., 70.0, False, False],
#        ...,
#        ['2022-12-18', 'Argentina', 'France', ..., 81.0, False, False],
#        ['2022-12-18', 'Argentina', 'France', ..., 109.0, False, False],
#        ['2022-12-18', 'Argentina', 'France', ..., 118.0, False, True]],
#       dtype=object)

# %%
#slicing
df2=df[0:5]

# %%
df2
# Out:
#          date  home_team away_team       team            scorer  minute  \
# 0  1916-07-02      Chile   Uruguay    Uruguay   José Piendibene    44.0
# 1  1916-07-02      Chile   Uruguay    Uruguay  Isabelino Gradín    55.0
# 2  1916-07-02      Chile   Uruguay    Uruguay  Isabelino Gradín    70.0
# 3  1916-07-02      Chile   Uruguay    Uruguay   José Piendibene    75.0
# 4  1916-07-06  Argentina     Chile  Argentina     Alberto Ohaco     2.0
#
#    own_goal  penalty
# 0     False    False
# 1     False    False
# 2     False    False
# 3     False    False
# 4     False    False

# %%
#result on condition basis
df[df.minute>70.0]
# Out:
#              date  home_team away_team       team                scorer  \
# 3      1916-07-02      Chile   Uruguay    Uruguay       José Piendibene
# 9      1916-07-06  Argentina     Chile  Argentina         Alberto Ohaco
# 10     1916-07-06  Argentina     Chile  Argentina  Alberto Marcovecchio
# 12     1916-07-08     Brazil     Chile      Chile      Hernando Salazar
# 17     1916-07-12     Brazil   Uruguay    Uruguay          Jose Tognola
# ...           ...        ...       ...        ...                   ...
# 40998  2022-12-14     France   Morocco     France     Randal Kolo Muani
# 41004  2022-12-18  Argentina    France     France         Kylian Mbappé
# 41005  2022-12-18  Argentina    France     France         Kylian Mbappé
# 41006  2022-12-18  Argentina    France  Argentina          Lionel Messi
# 41007  2022-12-18  Argentina    France     France         Kylian Mbappé
#
#        minute  own_goal  penalty
# 3        75.0     False    False
# 9        75.0     False    False
# ...

# %%
#copy data from original data
copied_df=df.copy()

# %%
copied_df
# Out:
#              date  home_team away_team       team            scorer  minute  \
# 0      1916-07-02      Chile   Uruguay    Uruguay   José Piendibene    44.0
# 1      1916-07-02      Chile   Uruguay    Uruguay  Isabelino Gradín    55.0
# 2      1916-07-02      Chile   Uruguay    Uruguay  Isabelino Gradín    70.0
# 3      1916-07-02      Chile   Uruguay    Uruguay   José Piendibene    75.0
# 4      1916-07-06  Argentina     Chile  Argentina     Alberto Ohaco     2.0
# ...           ...        ...       ...        ...               ...     ...
# 41003  2022-12-18  Argentina    France  Argentina    Ángel Di María    36.0
# 41004  2022-12-18  Argentina    France     France     Kylian Mbappé    80.0
# 41005  2022-12-18  Argentina    France     France     Kylian Mbappé    81.0
# 41006  2022-12-18  Argentina    France  Argentina      Lionel Messi   109.0
# 41007  2022-12-18  Argentina    France     France     Kylian Mbappé   118.0
#
#        own_goal  penalty
# 0         False    False
# ...

# %%
a=df.groupby('penalty')

# %%
a.first()
# Out:
#                date  home_team away_team       team              scorer  \
# penalty
# False    1916-07-02      Chile   Uruguay    Uruguay     José Piendibene
# True     1916-07-06  Argentina     Chile  Argentina  Juan Domingo Brown
#
#          minute  own_goal
# penalty
# False      44.0     False
# True       60.0     False

# %%
df.iloc[1:4,[0]]
# Out:
#          date
# 1  1916-07-02
# 2  1916-07-02
# 3  1916-07-02

# %%
df.iloc[1:10,[7]]
# Out:
#    penalty
# 1    False
# 2    False
# 3    False
# 4    False
# 5    False
# 6     True
# 7     True
# 8    False
# 9    False

# %%
df.loc[1:12,['own_goal']]
# Out:
#     own_goal
# 1      False
# 2      False
# 3      False
# 4      False
# 5      False
# 6      False
# 7      False
# 8      False
# 9      False
# 10     False
# 11     False
# 12     False

# %%
df.plot()
# Out:
# <AxesSubplot:>

# %%
df.shape
# Out:
# (41008, 8)

# %%
#to get the data from column name scorer
df['scorer']
# Out:
# 0         José Piendibene
# 1        Isabelino Gradín
# 2        Isabelino Gradín
# 3         José Piendibene
# 4           Alberto Ohaco
#                ...
# 41003      Ángel Di María
# 41004       Kylian Mbappé
# 41005       Kylian Mbappé
# 41006        Lionel Messi
# 41007       Kylian Mbappé
# Name: scorer, Length: 41008, dtype: object

# %%
a=df['scorer']
type(a)
# Out:
# pandas.core.series.Series

# %% [markdown]
# # 1.How many goals by Kylian Mbappe from the given dataset?

# %%
c=df['scorer']='Kylian Mbappe'

# %%
count=0
for i in c:
    count=count+1
print(count)
# Out:
# 13

# %% [markdown]
# # 2.How many home team in this given data?

# %%
len(df['home_team'].unique())
# Out:
# 220

# %% [markdown]
# # 3.How many goals scored by Lionel Messi?

# %%
d=df['scorer']='Lionel Messi'

# %%
count=0
for i in d:
    count=count+1
print(count)
# Out:
# 12

# %% [markdown]
# # 4.Print the teams name?

# %%
e=df['team'].unique()

# %%
for i in e:
    print(i)
# Out:
# Uruguay
# Argentina
# Chile
# Brazil
# Paraguay
# Bolivia
# Peru
# United States
# France
# Mexico
# Yugoslavia
# Romania
# Sweden
# Estonia
# Switzerland
# Czechoslovakia
# Poland
# Cuba
# Haiti
# Belgium
# Republic of Ireland
# Germany
# Luxembourg
# Spain
# Egypt
# Israel
# Portugal
# Bulgaria
# Hungary
# Italy
# Netherlands
# Austria
# Latvia
# Lithuania
# Norway
# Greece
# Ecuador
# Colombia
# Scotland
# Northern Ireland
# Finland
# England
# Wales
# Turkey
# Saarland
# Japan
# South Korea
# Hong Kong
# Vietnam Republic
# Denmark
# Costa Rica
# Guatemala
# Sudan
# Curaçao
# Indonesia
# German DR
# Syria
# China PR
# Iceland
# Canada
# Russia
# Ghana
# Nigeria
# Honduras
# Suriname
# Taiwan
# Morocco
# Tunisia
# Cyprus
# Ethiopia
# Uganda
# Malta
# Albania
# India
# Jamaica
# Trinidad and Tobago
# Venezuela
# DR Congo
# Ivory Coast
# Senegal
# North Korea
# Australia
# Algeria
# Congo
# Iran
# Myanmar
# Zambia
# Bermuda
# El Salvador
# Cameroon
# Libya
# Zimbabwe
# Guinea
# ...

# %%
f=df[df['penalty']=='FALSE']

# %%
count=0
for i in f:
    count=count+1
print(count)
# Out:
# 8
